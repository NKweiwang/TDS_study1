# %%
nums = list(range(1,10))
target = 7
k = 6
res = []
path = []
def findk(nums,crtsum,k,res,path,i):
#     if len(path)>=2 and path[-1] in path[:-1]:
#         return
    if crtsum ==0:
        if k ==0:
            res.append(path)
            #print('add',path)
        #print("back")
        return
    if crtsum < 0:
        #print("back")
        return
    for ii in range(i,len(nums)):
        #print(ii,"ii",crtsum -  nums[ii])
        findk(nums,crtsum -  nums[ii],k-1,res,path+[nums[ii]],ii)
findk(nums,target,k,res,path,0)
res
# Out:
# [[1, 1, 1, 1, 1, 2]]

# %%
nums = list(range(1,10))
target = 11
k = 3
res = []
path = []
def findk(nums,crtsum,k,res,path,i):
#     if len(path)>=2 and path[-1] in path[:-1]:
#         return
    print(path)
    if crtsum ==0:
        if k ==0:
            res.append(path)
            #print('add',path)
        #print("back")
        return
    if crtsum < 0 or k < 0:
        #print("back")
        return
    for ii in range(i+1,len(nums)):
        print(ii)
        #print(ii,"ii",crtsum -  nums[ii])
        findk(nums,crtsum -  nums[ii], k-1, res, path+[nums[ii]], ii)
findk(nums,target,k,res,path,-1)
res
# Out:
# []
# 0
# [1]
# 1
# [1, 2]
# 2
# [1, 2, 3]
# 3
# [1, 2, 3, 4]
# 4
# [1, 2, 3, 5]
# 5
# [1, 2, 3, 6]
# 6
# [1, 2, 3, 7]
# 7
# [1, 2, 3, 8]
# 8
# [1, 2, 3, 9]
# 3
# [1, 2, 4]
# 4
# [1, 2, 4, 5]
# 5
# [1, 2, 4, 6]
# 6
# [1, 2, 4, 7]
# 7
# [1, 2, 4, 8]
# 8
# [1, 2, 4, 9]
# 4
# [1, 2, 5]
# 5
# [1, 2, 5, 6]
# 6
# [1, 2, 5, 7]
# 7
# [1, 2, 5, 8]
# 8
# [1, 2, 5, 9]
# 5
# [1, 2, 6]
# 6
# [1, 2, 6, 7]
# 7
# [1, 2, 6, 8]
# 8
# [1, 2, 6, 9]
# 6
# [1, 2, 7]
# 7
# [1, 2, 7, 8]
# 8
# [1, 2, 7, 9]
# 7
# [1, 2, 8]
# 8
# [1, 2, 9]
# 2
# [1, 3]
# 3
# [1, 3, 4]
# 4
# [1, 3, 4, 5]
# 5
# [1, 3, 4, 6]
# 6
# [1, 3, 4, 7]
# 7
# [1, 3, 4, 8]
# 8
# [1, 3, 4, 9]
# 4
# [1, 3, 5]
# 5
# [1, 3, 5, 6]
# 6
# [1, 3, 5, 7]
# 7
# [1, 3, 5, 8]
# 8
# [1, 3, 5, 9]
# 5
# [1, 3, 6]
# 6
# [1, 3, 6, 7]
# 7
# [1, 3, 6, 8]
# 8
# [1, 3, 6, 9]
# 6
# [1, 3, 7]
# 7
# [1, 3, 8]
# 8
# [1, 3, 9]
# 3
# [1, 4]
# 4
# [1, 4, 5]
# 5
# [1, 4, 5, 6]
# 6
# [1, 4, 5, 7]
# 7
# [1, 4, 5, 8]
# 8
# [1, 4, 5, 9]
# 5
# [1, 4, 6]
# 6
# [1, 4, 7]
# 7
# ...
