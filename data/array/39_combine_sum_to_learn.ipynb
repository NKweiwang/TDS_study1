# %%
nums = [2,3,4,6,7]
target = 10
results = []
result = []
def search(nums,target):
    i = 0
    j = len(nums)-1
    if nums[j] == target: return True
    while j>i:
        mid = round((i+j)/2)
        if nums[mid] == target:
            return True
        if nums[mid] < target:
            i = mid
        if nums[mid] > target:
            j = mid
        if j-i ==1 and nums[i] != target and nums[j] != target:
            return False
        print(i,j)
    return False
def unit1(nums,target,i,results,result):
    print(result,i)
    if target<0: return
    if target ==0:
        results.append(result)
        return
    else:
        for j in range(i,len(nums)):
            print(j)
            unit1(nums,target - nums[j],j,results, result + [nums[j]])
        
        
unit1(nums,target,0,results,result)
results
# Out:
# [] 0
# 0
# [2] 0
# 0
# [2, 2] 0
# 0
# [2, 2, 2] 0
# 0
# [2, 2, 2, 2] 0
# 0
# [2, 2, 2, 2, 2] 0
# 1
# [2, 2, 2, 2, 3] 1
# 2
# [2, 2, 2, 2, 4] 2
# 3
# [2, 2, 2, 2, 6] 3
# 4
# [2, 2, 2, 2, 7] 4
# 1
# [2, 2, 2, 3] 1
# 1
# [2, 2, 2, 3, 3] 1
# 2
# [2, 2, 2, 3, 4] 2
# 3
# [2, 2, 2, 3, 6] 3
# 4
# [2, 2, 2, 3, 7] 4
# 2
# [2, 2, 2, 4] 2
# 3
# [2, 2, 2, 6] 3
# 4
# [2, 2, 2, 7] 4
# 1
# [2, 2, 3] 1
# 1
# [2, 2, 3, 3] 1
# 2
# [2, 2, 3, 4] 2
# 3
# [2, 2, 3, 6] 3
# 4
# [2, 2, 3, 7] 4
# 2
# [2, 2, 4] 2
# 2
# [2, 2, 4, 4] 2
# 3
# [2, 2, 4, 6] 3
# 4
# [2, 2, 4, 7] 4
# 3
# [2, 2, 6] 3
# 4
# [2, 2, 7] 4
# 1
# [2, 3] 1
# 1
# [2, 3, 3] 1
# 1
# [2, 3, 3, 3] 1
# 2
# [2, 3, 3, 4] 2
# 3
# [2, 3, 3, 6] 3
# 4
# [2, 3, 3, 7] 4
# 2
# [2, 3, 4] 2
# 2
# [2, 3, 4, 4] 2
# 3
# [2, 3, 4, 6] 3
# 4
# [2, 3, 4, 7] 4
# 3
# [2, 3, 6] 3
# 4
# [2, 3, 7] 4
# 2
# [2, 4] 2
# 2
# [2, 4, 4] 2
# 3
# [2, 4, 6] 3
# 4
# [2, 4, 7] 4
# 3
# [2, 6] 3
# 3
# [2, 6, 6] 3
# 4
# [2, 6, 7] 4
# 4
# [2, 7] 4
# 4
# [2, 7, 7] 4
# 1
# [3] 1
# 1
# ...

# %%
def test(nums,target):
    if target in nums: return True
nums=[2,3,4]
target = 5
test(nums,target)
